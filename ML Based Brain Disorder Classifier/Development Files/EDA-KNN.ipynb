# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Brain_Disorders.csv')
df
# Out:
#            Mean  Median  Mode  StandardDeviation  Skewness  Kurtosis  Disorder
# 0     41.262814     9.0     0          49.033682  1.153535  0.803457         1
# 1     42.984764    26.0     6          43.628437  1.044681  0.721944         1
# 2     53.817429    58.0     0          45.676158  0.679193  0.073624         1
# 3     52.908051    52.0     0          40.902117  0.726920  0.315372         1
# 4     55.840900    60.0     0          42.467546  0.534297 -0.059096         1
# ...         ...     ...   ...                ...       ...       ...       ...
# 5704  31.204391     5.0     0          39.139881  1.484026  2.998947         4
# 5705  31.116611     5.0     0          39.627535  1.413407  2.349073         4
# 5706  30.760464     4.0     0          39.759310  1.341760  1.782878         4
# 5707  30.714725     4.0     0          41.007297  1.405538  1.831738         4
# 5708  30.555187     3.0     0          42.205417  1.402105  1.598050         4
#
# [5709 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5709 entries, 0 to 5708
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Mean               5709 non-null   float64
#  1   Median             5709 non-null   float64
#  2   Mode               5709 non-null   int64
#  3   StandardDeviation  5709 non-null   float64
#  4   Skewness           5709 non-null   float64
#  5   Kurtosis           5709 non-null   float64
#  6   Disorder           5709 non-null   int64
# dtypes: float64(5), int64(2)
# memory usage: 312.3 KB

# %%
df.describe()
# Out:
#               Mean       Median         Mode  StandardDeviation     Skewness  \
# count  5709.000000  5709.000000  5709.000000        5709.000000  5709.000000
# mean     47.282153    32.143107     3.598353          47.288910     1.002320
# std      17.666261    27.815459    11.816810          13.301775     0.422469
# min       9.768337     0.000000     0.000000          20.827005    -0.623712
# 25%      35.102219     5.000000     0.000000          39.149187     0.739257
# 50%      44.377625    29.000000     0.000000          43.709764     1.000250
# 75%      54.355614    52.000000     4.000000          50.370667     1.251334
# max     137.764303   158.000000   255.000000         102.765390     3.631105
#
#           Kurtosis     Disorder
# count  5709.000000  5709.000000
# mean      0.838969     2.441583
# std       1.347713     1.104378
# min      -1.754891     1.000000
# 25%       0.012633     1.000000
# 50%       0.656808     2.000000
# 75%       1.499382     3.000000
# ...

# %%
df.corr()
# Out:
#                        Mean    Median      Mode  StandardDeviation  Skewness  \
# Mean               1.000000  0.792857  0.362141           0.729931 -0.687080
# Median             0.792857  1.000000  0.287318           0.251059 -0.721524
# Mode               0.362141  0.287318  1.000000           0.140258 -0.147798
# StandardDeviation  0.729931  0.251059  0.140258           1.000000 -0.276601
# Skewness          -0.687080 -0.721524 -0.147798          -0.276601  1.000000
# Kurtosis          -0.563708 -0.386365 -0.081511          -0.460250  0.847896
# Disorder          -0.416964 -0.430538 -0.111537          -0.188952  0.352145
#
#                    Kurtosis  Disorder
# Mean              -0.563708 -0.416964
# Median            -0.386365 -0.430538
# Mode              -0.081511 -0.111537
# StandardDeviation -0.460250 -0.188952
# Skewness           0.847896  0.352145
# Kurtosis           1.000000  0.175766
# Disorder           0.175766  1.000000

# %%
print(len(df['Mean'].unique()))
print(len(df['Median'].unique()))
print(len(df['Mode'].unique()))
print(len(df['StandardDeviation'].unique()))
print(len(df['Skewness'].unique()))
print(len(df['Kurtosis'].unique()))
print(len(df['Disorder'].unique()))
# Out:
# 5500
# 138
# 57
# 5501
# 5501
# 5501
# 4

# %%
figure = plt.figure(figsize = (16, 9))
sns.countplot(x = df['Median'])
plt.show()

# %%
figure = plt.figure(figsize = (16, 9))
sns.countplot(x = df['Mode'])
plt.show()

# %%
figure = plt.figure(figsize = (16, 9))
sns.countplot(x = df['Disorder'])
plt.show()

# %%
sns.heatmap(df.corr(), annot = True, cmap = 'inferno')
plt.show()

# %%
df
# Out:
#            Mean  Median  Mode  StandardDeviation  Skewness  Kurtosis  Disorder
# 0     41.262814     9.0     0          49.033682  1.153535  0.803457         1
# 1     42.984764    26.0     6          43.628437  1.044681  0.721944         1
# 2     53.817429    58.0     0          45.676158  0.679193  0.073624         1
# 3     52.908051    52.0     0          40.902117  0.726920  0.315372         1
# 4     55.840900    60.0     0          42.467546  0.534297 -0.059096         1
# ...         ...     ...   ...                ...       ...       ...       ...
# 5704  31.204391     5.0     0          39.139881  1.484026  2.998947         4
# 5705  31.116611     5.0     0          39.627535  1.413407  2.349073         4
# 5706  30.760464     4.0     0          39.759310  1.341760  1.782878         4
# 5707  30.714725     4.0     0          41.007297  1.405538  1.831738         4
# 5708  30.555187     3.0     0          42.205417  1.402105  1.598050         4
#
# [5709 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

ss = StandardScaler()
knn = KNeighborsClassifier(n_neighbors = 5, weights = 'distance', p = 5, algorithm = 'kd_tree', leaf_size = 80, metric = 'euclidean')
df = pd.read_csv('Brain_Disorders.csv')
x = df.iloc[:, 0:6]
y = df.iloc[:, 6]
x = ss.fit_transform(x)
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 23)
model = knn.fit(X_train, y_train)
y_pred = model.predict(X_test)
y_train_pred = model.predict(X_train)

print('\nTesting Data:\n')
print('\nAccuracy Score = ', accuracy_score(y_test, y_pred))
print('\nPrecision Score = ', precision_score(y_test, y_pred, average='macro'))
print('\nRecall Score = ', recall_score(y_test, y_pred, average='macro'))
print('\nf1 Score = ', f1_score(y_test, y_pred, average='macro'))
print('\nConfusion Matrix:\n\n', confusion_matrix(y_test, y_pred))
print('\nClassification Report:\n\n', classification_report(y_test, y_pred))

print('\nTraining Data:\n')
print('\nAccuracy Score = ', accuracy_score(y_train, y_train_pred))
print('\nPrecision Score = ', precision_score(y_train, y_train_pred, average='macro'))
print('\nRecall Score = ', recall_score(y_train, y_train_pred, average='macro'))
print('\nf1 Score = ', f1_score(y_train, y_train_pred, average='macro'))
print('\nConfusion Matrix:\n\n', confusion_matrix(y_train, y_train_pred))
print('\nClassification Report:\n\n', classification_report(y_train, y_train_pred))

plt.figure(figsize = (8, 6))
sns.heatmap(confusion_matrix(y_test, y_pred), annot = True, cmap = 'inferno')
plt.show()
# Out:
# Testing Data:
#
#
# Accuracy Score =  0.861646234676007
#
# Precision Score =  0.8548422503287428
#
# Recall Score =  0.8514512372774147
#
# f1 Score =  0.8515809681081178
#
# Confusion Matrix:
#
#  [[264   3  13   8]
#  [  4 328   3   1]
#  [ 18  11 207  25]
#  [ 18   3  51 185]]
#
# Classification Report:
#
#                precision    recall  f1-score   support
#
#            1       0.87      0.92      0.89       288
#            2       0.95      0.98      0.96       336
#            3       0.76      0.79      0.77       261
#            4       0.84      0.72      0.78       257
#
#     accuracy                           0.86      1142
#    macro avg       0.85      0.85      0.85      1142
# weighted avg       0.86      0.86      0.86      1142
#
#
# Training Data:
#
#
# Accuracy Score =  1.0
#
# Precision Score =  1.0
#
# Recall Score =  1.0
#
# f1 Score =  1.0
#
# Confusion Matrix:
#
#  [[1169    0    0    0]
#  [   0 1258    0    0]
#  [   0    0 1077    0]
# ...

# %% [markdown]
# # NEW TESTING DATA

# %%
testdata = pd.read_csv('Brain(Test).csv')
testdata
# Out:
#            Mean  Median  Mode  StandardDeviation  Skewness  Kurtosis  Disorder
# 0     47.193092    42.0     0          47.283395  0.620051 -0.609054         1
# 1     53.698257    57.0     6          43.666014  0.704561  0.382898         1
# 2     45.484921    15.0     0          50.996201  1.161252  0.688310         1
# 3     61.785351    67.0     4          42.920597  0.787690  1.498105         1
# 4     51.488476    56.0     3          36.993385  0.855566  1.581881         1
# ...         ...     ...   ...                ...       ...       ...       ...
# 1303  26.288933     4.0     0          37.493148  1.374213  0.987634         4
# 1304  26.575390     2.0     0          36.764815  1.352844  1.651926         4
# 1305  24.149101     2.0     0          38.266806  1.648782  2.213791         4
# 1306  29.126751     5.0     0          36.335492  1.357619  2.293800         4
# 1307  30.113461     4.0     0          41.733671  1.357189  1.055845         4
#
# [1308 rows x 7 columns]

# %%
model = knn.fit(x, y)
xtest = testdata.iloc[:, 0:6]
ytest = testdata.iloc[:, 6]
xtest = ss.fit_transform(xtest)
ytestpred = model.predict(xtest)
ytestpred
# Out:
# array([1, 1, 3, ..., 4, 2, 4], dtype=int64)

# %%
print('Accuracy = ', accuracy_score(ytest, ytestpred))
# Out:
# Accuracy =  0.7851681957186545

# %%
sns.heatmap(confusion_matrix(ytest, ytestpred), annot = True, cmap = 'inferno')
plt.show()
