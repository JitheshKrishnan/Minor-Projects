# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('transfusion (1).csv')
df.iloc[:, 4].value_counts()
# Out:
# -    570
# 3     23
# 5     23
# 0     22
# 1     22
# 2     22
# 4     22
# 6     22
# 7     22
# Name: Numbers, dtype: int64

# %%
df.iloc[:, 5].value_counts()
# Out:
# 0    570
# 1    178
# Name: whether he/she donated blood in March 2007, dtype: int64

# %%
df
# Out:
#      Recency (months)  Frequency (times)  Monetary (c.c. blood)  \
# 0                   2                 50                  12500
# 1                   0                 13                   3250
# 2                   1                 16                   4000
# 3                   2                 20                   5000
# 4                   1                 24                   6000
# ..                ...                ...                    ...
# 743                23                  2                    500
# 744                21                  2                    500
# 745                23                  3                    750
# 746                39                  1                    250
# 747                72                  1                    250
#
#      Time (months) Numbers  whether he/she donated blood in March 2007
# 0               98       0                                           1
# ...

# %%
df['Numbers'].unique()
# Out:
# array(['0', '1', '2', '3', '-', '4', '5', '6', '7'], dtype=object)

# %%
xones = df.groupby('whether he/she donated blood in March 2007')
ones = xones.get_group(1)
ones.index
# Out:
# Int64Index([  0,   1,   2,   3,   6,   8,   9,  12,  14,  15,
#             ...
#             639, 640, 644, 667, 669, 680, 695, 708, 712, 732],
#            dtype='int64', length=178)

# %%
x = [0, 1, 2, 3, 4, 5, 6, 7, 0, 1, 2, 3, 4, 5, 6, 7, 0, 1, 2, 3, 4, 5, 6, 7, 0, 1, 2, 3, 4, 5, 6, 7, 0, 1, 2, 3, 4, 5, 6, 7, 0, 1, 2, 3, 4, 5, 6, 7, 0, 1, 2, 3, 4, 5, 6, 7, 0, 1, 2, 3, 4, 5, 6, 7, 0, 1, 2, 3, 4, 5, 6, 7, 0, 1, 2, 3, 4, 5, 6, 7, 0, 1, 2, 3, 4, 5, 6, 7, 0, 1, 2, 3, 4, 5, 6, 7 , 0, 1, 2, 3, 4, 5, 6, 7, 0, 1, 2, 3, 4, 5, 6, 7, 0, 1, 2, 3, 4, 5, 6, 7, 0, 1, 2, 3, 4, 5, 6, 7, 0, 1, 2, 3, 4, 5, 6, 7, 0, 1, 2, 3, 4, 5, 6, 7, 0, 1, 2, 3, 4, 5, 6, 7, 0, 1, 2, 3, 4, 5, 6, 7, 0, 1, 2, 3, 4, 5, 6, 7, 0, 1, 2, 3, 4, 5, 6, 7, 5, 3]
len(x)
# Out:
# 178

# %%
df['Numbers'] = df['Numbers'].replace('-', np.random.randint(0, 8))

# %%
df
# Out:
#      Recency (months)  Frequency (times)  Monetary (c.c. blood)  \
# 0                   2                 50                  12500
# 1                   0                 13                   3250
# 2                   1                 16                   4000
# 3                   2                 20                   5000
# 4                   1                 24                   6000
# ..                ...                ...                    ...
# 743                23                  2                    500
# 744                21                  2                    500
# 745                23                  3                    750
# 746                39                  1                    250
# 747                72                  1                    250
#
#      Time (months) Numbers  whether he/she donated blood in March 2007
# 0               98       0                                           1
# ...

# %%
df['Numbers'] = df['Numbers'].astype(str)

# %%
df['Numbers'].unique()
# Out:
# array(['0', '1', '2', '3', '5', '4', '6', '7'], dtype=object)

# %%
df['Numbers'] = df['Numbers'].replace('0', 'A+ve')
df['Numbers'] = df['Numbers'].replace('1', 'A-ve')
df['Numbers'] = df['Numbers'].replace('2', 'B+ve')
df['Numbers'] = df['Numbers'].replace('3', 'B-ve')
df['Numbers'] = df['Numbers'].replace('4', 'AB+ve')
df['Numbers'] = df['Numbers'].replace('5', 'AB-ve')
df['Numbers'] = df['Numbers'].replace('6', 'O+ve')
df['Numbers'] = df['Numbers'].replace('7', 'O-ve')
df
# Out:
#      Recency (months)  Frequency (times)  Monetary (c.c. blood)  \
# 0                   2                 50                  12500
# 1                   0                 13                   3250
# 2                   1                 16                   4000
# 3                   2                 20                   5000
# 4                   1                 24                   6000
# ..                ...                ...                    ...
# 743                23                  2                    500
# 744                21                  2                    500
# 745                23                  3                    750
# 746                39                  1                    250
# 747                72                  1                    250
#
#      Time (months) Numbers  whether he/she donated blood in March 2007
# 0               98    A+ve                                           1
# ...

# %%
df['Numbers'].unique()
# Out:
# array(['A+ve', 'A-ve', 'B+ve', 'B-ve', 'AB-ve', 'AB+ve', 'O+ve', 'O-ve'],
#       dtype=object)

# %%
a = np.random.randint(6000000000, 10000000000, size=748, dtype=np.int64)
df.insert(5, 'Phone Number', a)

# %%
df
# Out:
#      Recency (months)  Frequency (times)  Monetary (c.c. blood)  \
# 0                   2                 50                  12500
# 1                   0                 13                   3250
# 2                   1                 16                   4000
# 3                   2                 20                   5000
# 4                   1                 24                   6000
# ..                ...                ...                    ...
# 743                23                  2                    500
# 744                21                  2                    500
# 745                23                  3                    750
# 746                39                  1                    250
# 747                72                  1                    250
#
#      Time (months) Numbers  Phone Number  \
# 0               98    A+ve    7589248946
# 1               28    A-ve    7692555460
# 2               35    B+ve    6510559185
# ...

# %%
df.to_csv('NewTransfusion.csv')
