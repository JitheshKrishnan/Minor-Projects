# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('transfusion.csv')
df
# Out:
#      Recency (months)  Frequency (times)  Monetary (c.c. blood)  \
# 0                   2                 50                  12500
# 1                   0                 13                   3250
# 2                   1                 16                   4000
# 3                   2                 20                   5000
# 4                   1                 24                   6000
# ..                ...                ...                    ...
# 743                23                  2                    500
# 744                21                  2                    500
# 745                23                  3                    750
# 746                39                  1                    250
# 747                72                  1                    250
#
#      Time (months)  whether he/she donated blood in March 2007
# 0               98                                           1
# 1               28                                           1
# ...

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 1, figsize = (16, 9))
sns.distplot(df.iloc[:, 0], ax = axes[0], color = 'red')
df.iloc[:, 0] = df.iloc[:, 0].apply(np.log1p)
sns.distplot(df.iloc[:, 0], ax = axes[1], color = 'green')
plt.show()
print(df.iloc[:, 0].skew())
# Out:
# C:\Users\Radhakrishnan P\AppData\Local\Temp\ipykernel_7476\672849586.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.iloc[:, 0], ax = axes[0], color = 'red')
# C:\Users\Radhakrishnan P\AppData\Local\Temp\ipykernel_7476\672849586.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 1, figsize = (16, 9))
sns.distplot(df.iloc[:, 1], ax = axes[0], color = 'red')
df.iloc[:, 1] = df.iloc[:, 1].apply(np.log1p)
sns.distplot(df.iloc[:, 1], ax = axes[1], color = 'green')
plt.show()
print(df.iloc[:, 1].skew())
# Out:
# C:\Users\Radhakrishnan P\AppData\Local\Temp\ipykernel_7476\3883728451.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.iloc[:, 1], ax = axes[0], color = 'red')
# C:\Users\Radhakrishnan P\AppData\Local\Temp\ipykernel_7476\3883728451.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 1, figsize = (16, 9))
sns.distplot(df.iloc[:, 2], ax = axes[0], color = 'red')
df.iloc[:, 2] = df.iloc[:, 2].apply(np.log1p)
sns.distplot(df.iloc[:, 2], ax = axes[1], color = 'green')
plt.show()
print(df.iloc[:, 2].skew())
# Out:
# C:\Users\Radhakrishnan P\AppData\Local\Temp\ipykernel_7476\4279984534.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.iloc[:, 2], ax = axes[0], color = 'red')
# C:\Users\Radhakrishnan P\AppData\Local\Temp\ipykernel_7476\4279984534.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 1, figsize = (16, 9))
sns.distplot(df.iloc[:, 3], ax = axes[0], color = 'red')
df.iloc[:, 3] = df.iloc[:, 3].apply(np.log1p)
sns.distplot(df.iloc[:, 3], ax = axes[1], color = 'green')
plt.show()
print(df.iloc[:, 3].skew())
# Out:
# C:\Users\Radhakrishnan P\AppData\Local\Temp\ipykernel_7476\2488972106.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.iloc[:, 3], ax = axes[0], color = 'red')
# C:\Users\Radhakrishnan P\AppData\Local\Temp\ipykernel_7476\2488972106.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
sns.heatmap(df.corr(), annot = True, cmap = 'viridis')
plt.show()

# %%
df_zeros = df[df.iloc[:, -1] != 1]
df_zeros
# Out:
#      Recency (months)  Frequency (times)  Monetary (c.c. blood)  \
# 4            0.693147           3.218876               8.699681
# 5            1.609438           1.609438               6.908755
# 7            0.693147           2.564949               8.006701
# 10           1.609438           3.178054               8.657129
# 11           0.000000           1.386294               6.621406
# ..                ...                ...                    ...
# 743          3.178054           1.098612               6.216606
# 744          3.091042           1.098612               6.216606
# 745          3.178054           1.386294               6.621406
# 746          3.688879           0.693147               5.525453
# 747          4.290459           0.693147               5.525453
#
#      Time (months)  whether he/she donated blood in March 2007
# 4         4.356709                                           0
# 5         1.609438                                           0
# ...

# %%
import math
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
ss = StandardScaler()
knn = KNeighborsClassifier(n_neighbors = 21, p = 2, metric = 'euclidean')
x = df.iloc[:, [0,2,3]]
y = df.iloc[:, 4]
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 135)
X_train = ss.fit_transform(X_train)
X_test = ss.transform(X_test)
model = knn.fit(X_train, y_train)
y_pred = model.predict(X_test)
y_train_pred = model.predict(X_train)
print('\nAccuracy Score(Test Data) = ', accuracy_score(y_test, y_pred))
print('\nAccuracy Score(Train Data) = ', accuracy_score(y_train, y_train_pred))
print('\nPrecision Score = ', precision_score(y_test, y_pred))
print('\nRecall Score = ', recall_score(y_test, y_pred))
print('\nf1 Score = ', f1_score(y_test, y_pred))
print('\nConfusion Matrix:\n\n', confusion_matrix(y_test, y_pred))
print('\nClassification Report:\n\n', classification_report(y_test, y_pred))
plt.figure(figsize = (8, 6))
sns.heatmap(confusion_matrix(y_test, y_pred), annot = True, cmap = 'viridis')
plt.show()
fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize = (16, 9))
sns.boxplot(df.iloc[:, 0], color = 'red', ax = axes[0, 0])
sns.boxplot(df.iloc[:, 1], color = 'green', ax = axes[0, 1])
sns.boxplot(df.iloc[:, 2], color = 'blue', ax = axes[1, 0])
sns.boxplot(df.iloc[:, 3], color = 'orange', ax = axes[1, 1])
axes[0, 0].set_title('Recency')
axes[0, 1].set_title('Frequency')
axes[1, 0].set_title('Monetary')
axes[1, 1].set_title('Time')
plt.show()
# Out:
# Accuracy Score(Test Data) =  0.8866666666666667
#
# Accuracy Score(Train Data) =  0.7759197324414716
#
# Precision Score =  0.7058823529411765
#
# Recall Score =  0.5
#
# f1 Score =  0.5853658536585366
#
# Confusion Matrix:
#
#  [[121   5]
#  [ 12  12]]
#
# Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93       126
#            1       0.71      0.50      0.59        24
#
#     accuracy                           0.89       150
#    macro avg       0.81      0.73      0.76       150
# weighted avg       0.88      0.89      0.88       150

# %%
recency = df_zeros.iloc[:, 0]
recency = pd.DataFrame(recency)
print(recency)

frequency = df_zeros.iloc[:, 1]
frequency = pd.DataFrame(frequency)
print(frequency)

monetary = df_zeros.iloc[:, 2]
monetary = pd.DataFrame(monetary)
print(monetary)

time = df_zeros.iloc[:, 3]
time = pd.DataFrame(time)
print(time)
# Out:
#      Recency (months)
# 4                   1
# 5                   4
# 7                   1
# 10                  4
# 11                  0
# ..                ...
# 743                23
# 744                21
# 745                23
# 746                39
# 747                72
#
# [570 rows x 1 columns]
#      Frequency (times)
# 4                   24
# 5                    4
# 7                   12
# 10                  23
# 11                   3
# ..                 ...
# 743                  2
# 744                  2
# 745                  3
# 746                  1
# 747                  1
#
# [570 rows x 1 columns]
#      Monetary (c.c. blood)
# 4                     6000
# 5                     1000
# 7                     3000
# 10                    5750
# 11                     750
# ..                     ...
# 743                    500
# 744                    500
# 745                    750
# 746                    250
# 747                    250
#
# ...

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 1, figsize = (16, 18))
sns.boxplot(recency, color = 'red', ax = axes[0])
axes[0].set_title('Recency Column')

Q1 = recency.quantile(0.25)
Q3 = recency.quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5*IQR
upper_bound = Q3 + 1.5*IQR

Recency = recency[(recency >= lower_bound) & (recency <= upper_bound)]
outliers_recency = Recency[(recency < lower_bound) | (recency > upper_bound)]
sns.boxplot(Recency, color = 'green', ax = axes[1])
axes[1].set_title('Recency Coulmn Without Outliers')
plt.show()

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 1, figsize = (16, 18))
sns.boxplot(frequency, color = 'red', ax = axes[0])
axes[0].set_title('Frequency Column')

Q1 = frequency.quantile(0.25)
Q3 = frequency.quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5*IQR
upper_bound = Q3 + 1.5*IQR

Frequency = frequency[(frequency >= lower_bound) & (frequency <= upper_bound)]
outliers_frequency = frequency[(frequency < lower_bound) | (frequency > upper_bound)]
sns.boxplot(Frequency, color = 'green', ax = axes[1])
axes[1].set_title('Frequency Coulmn Without Outliers')
plt.show()

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 1, figsize = (16, 18))
sns.boxplot(monetary, color = 'red', ax = axes[0])
axes[0].set_title('Monetary Column')

Q1 = monetary.quantile(0.25)
Q3 = monetary.quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5*IQR
upper_bound = Q3 + 1.5*IQR

Monetary = monetary[(monetary >= lower_bound) & (monetary <= upper_bound)]
outliers_monetary = monetary[(monetary < lower_bound) | (monetary > upper_bound)]
sns.boxplot(Monetary, color = 'green', ax = axes[1])
axes[1].set_title('Monetary Coulmn Without Outliers')
plt.show()

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 1, figsize = (16, 18))
sns.boxplot(time, color = 'red', ax = axes[0])
axes[0].set_title('Time Column')

Q1 = time.quantile(0.25)
Q3 = time.quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5*IQR
upper_bound = Q3 + 1.5*IQR

Time = time[(time >= lower_bound) & (time <= upper_bound)]
outliers_time = time[(time < lower_bound) | (time > upper_bound)]
sns.boxplot(Time, color = 'green', ax = axes[1])
axes[1].set_title('Time Coulmn Without Outliers')
plt.show()
