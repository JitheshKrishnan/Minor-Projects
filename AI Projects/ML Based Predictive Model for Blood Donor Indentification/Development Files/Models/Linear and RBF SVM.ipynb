# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
ss = StandardScaler()
svm = SVC(kernel = 'linear')
df = pd.read_csv('transfusion.csv')
x = df.iloc[:, 0:4]
y = df.iloc[:, 4]
x = ss.fit_transform(x)
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 266)
model = svm.fit(X_train, y_train)
y_pred = model.predict(X_test)
print('\nAccuracy Score = ', accuracy_score(y_test, y_pred))
print('\nPrecision Score = ', precision_score(y_test, y_pred))
print('\nRecall Score = ', recall_score(y_test, y_pred))
print('\nf1 Score = ', f1_score(y_test, y_pred))
print('\nConfusion Matrix:\n\n', confusion_matrix(y_test, y_pred))
print('\nClassification Report:\n\n', classification_report(y_test, y_pred))
plt.figure(figsize = (8, 6))
sns.heatmap(confusion_matrix(y_test, y_pred), annot = True, cmap = 'magma')
plt.show()
fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize = (16, 9))
sns.boxplot(df.iloc[:, 0], color = 'red', ax = axes[0, 0])
sns.boxplot(df.iloc[:, 1], color = 'green', ax = axes[0, 1])
sns.boxplot(df.iloc[:, 2], color = 'blue', ax = axes[1, 0])
sns.boxplot(df.iloc[:, 3], color = 'orange', ax = axes[1, 1])
axes[0, 0].set_title('Recency')
axes[0, 1].set_title('Frequency')
axes[1, 0].set_title('Monetary')
axes[1, 1].set_title('Time')
plt.show()
print('\nRecency:\n')
stats_recency = {'Mean':9.5, 'Median':7.0, 'Max':74, 'Min':0}
stats_recency = [{'Statistic': key, 'Value': value} for key, value in stats_recency.items()]
stats_recency = pd.DataFrame(stats_recency)
print(stats_recency)
print('\nFrequency:\n')
stats_frequency = {'Mean':5.5, 'Median':4.0, 'Max':50, 'Min':1}
stats_frequency = [{'Statistic': key, 'Value': value} for key, value in stats_frequency.items()]
stats_frequency = pd.DataFrame(stats_frequency)
print(stats_frequency)
print('\nMonetary:\n')
stats_monetary = {'Mean':1378.6, 'Median':1000, 'Max':12500, 'Min':250}
stats_monetary = [{'Statistic': key, 'Value': value} for key, value in stats_monetary.items()]
stats_monetary = pd.DataFrame(stats_monetary)
print(stats_monetary)
print('\nTime:\n')
stats_time = {'Mean':34.2, 'Median':28, 'Max':98, 'Min':2}
stats_time = [{'Statistic': key, 'Value': value} for key, value in stats_time.items()]
stats_time = pd.DataFrame(stats_time)
print(stats_time)
# Out:
# Accuracy Score =  0.8466666666666667
#
# Precision Score =  0.5
#
# Recall Score =  0.043478260869565216
#
# f1 Score =  0.08
#
# Confusion Matrix:
#
#  [[126   1]
#  [ 22   1]]
#
# Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.85      0.99      0.92       127
#            1       0.50      0.04      0.08        23
#
#     accuracy                           0.85       150
#    macro avg       0.68      0.52      0.50       150
# weighted avg       0.80      0.85      0.79       150
# Recency:
#
#   Statistic  Value
# 0      Mean    9.5
# 1    Median    7.0
# 2       Max   74.0
# 3       Min    0.0
#
# Frequency:
#
#   Statistic  Value
# 0      Mean    5.5
# 1    Median    4.0
# 2       Max   50.0
# 3       Min    1.0
#
# Monetary:
#
#   Statistic    Value
# 0      Mean   1378.6
# 1    Median   1000.0
# 2       Max  12500.0
# 3       Min    250.0
#
# Time:
#
#   Statistic  Value
# 0      Mean   34.2
# 1    Median   28.0
# 2       Max   98.0
# 3       Min    2.0

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
ss = StandardScaler()
svm = SVC(kernel = 'rbf')
df = pd.read_csv('transfusion.csv')
x = df.iloc[:, 0:4]
y = df.iloc[:, 4]
x = ss.fit_transform(x)
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 46)
model = svm.fit(X_train, y_train)
y_pred = model.predict(X_test)
print('\nAccuracy Score = ', accuracy_score(y_test, y_pred))
print('\nPrecision Score = ', precision_score(y_test, y_pred))
print('\nRecall Score = ', recall_score(y_test, y_pred))
print('\nf1 Score = ', f1_score(y_test, y_pred))
print('\nConfusion Matrix:\n\n', confusion_matrix(y_test, y_pred))
print('\nClassification Report:\n\n', classification_report(y_test, y_pred))
plt.figure(figsize = (8, 6))
sns.heatmap(confusion_matrix(y_test, y_pred), annot = True, cmap = 'magma')
plt.show()
fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize = (16, 9))
sns.boxplot(df.iloc[:, 0], color = 'red', ax = axes[0, 0])
sns.boxplot(df.iloc[:, 1], color = 'green', ax = axes[0, 1])
sns.boxplot(df.iloc[:, 2], color = 'blue', ax = axes[1, 0])
sns.boxplot(df.iloc[:, 3], color = 'orange', ax = axes[1, 1])
axes[0, 0].set_title('Recency')
axes[0, 1].set_title('Frequency')
axes[1, 0].set_title('Monetary')
axes[1, 1].set_title('Time')
plt.show()
print('\nRecency:\n')
stats_recency = {'Mean':9.5, 'Median':7.0, 'Max':74, 'Min':0}
stats_recency = [{'Statistic': key, 'Value': value} for key, value in stats_recency.items()]
stats_recency = pd.DataFrame(stats_recency)
print(stats_recency)
print('\nFrequency:\n')
stats_frequency = {'Mean':5.5, 'Median':4.0, 'Max':50, 'Min':1}
stats_frequency = [{'Statistic': key, 'Value': value} for key, value in stats_frequency.items()]
stats_frequency = pd.DataFrame(stats_frequency)
print(stats_frequency)
print('\nMonetary:\n')
stats_monetary = {'Mean':1378.6, 'Median':1000, 'Max':12500, 'Min':250}
stats_monetary = [{'Statistic': key, 'Value': value} for key, value in stats_monetary.items()]
stats_monetary = pd.DataFrame(stats_monetary)
print(stats_monetary)
print('\nTime:\n')
stats_time = {'Mean':34.2, 'Median':28, 'Max':98, 'Min':2}
stats_time = [{'Statistic': key, 'Value': value} for key, value in stats_time.items()]
stats_time = pd.DataFrame(stats_time)
print(stats_time)
# Out:
# Accuracy Score =  0.8733333333333333
#
# Precision Score =  0.8125
#
# Recall Score =  0.4482758620689655
#
# f1 Score =  0.5777777777777777
#
# Confusion Matrix:
#
#  [[118   3]
#  [ 16  13]]
#
# Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93       121
#            1       0.81      0.45      0.58        29
#
#     accuracy                           0.87       150
#    macro avg       0.85      0.71      0.75       150
# weighted avg       0.87      0.87      0.86       150
# Recency:
#
#   Statistic  Value
# 0      Mean    9.5
# 1    Median    7.0
# 2       Max   74.0
# 3       Min    0.0
#
# Frequency:
#
#   Statistic  Value
# 0      Mean    5.5
# 1    Median    4.0
# 2       Max   50.0
# 3       Min    1.0
#
# Monetary:
#
#   Statistic    Value
# 0      Mean   1378.6
# 1    Median   1000.0
# 2       Max  12500.0
# 3       Min    250.0
#
# Time:
#
#   Statistic  Value
# 0      Mean   34.2
# 1    Median   28.0
# 2       Max   98.0
# 3       Min    2.0

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
ss = StandardScaler()
svm = SVC(kernel = 'linear')
df = pd.read_csv('transfusion.csv')
x = df.iloc[:, 0:4]
y = df.iloc[:, 4]
x = ss.fit_transform(x)
acc = []
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 266)
model = svm.fit(X_train, y_train)
y_pred = model.predict(X_test)
acc.append(accuracy_score(y_test, y_pred))
acc = np.array(acc)
print('accuracy score = ', max(acc))
# Out:
# accuracy score =  0.8466666666666667

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
ss = StandardScaler()
svm = SVC(kernel = 'rbf')
df = pd.read_csv('transfusion.csv')
x = df.iloc[:, 0:4]
y = df.iloc[:, 4]
x = ss.fit_transform(x)
acc = []
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 46)
model = svm.fit(X_train, y_train)
y_pred = model.predict(X_test)
acc.append(accuracy_score(y_test, y_pred))
acc = np.array(acc)
print('accurcy score = ', max(acc))
# Out:
# accurcy score =  0.8733333333333333

# %% [markdown]
# # SVM(Linear) without the column 'Freqency (times)'

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
ss = StandardScaler()
svm = SVC(kernel = 'linear')
df = pd.read_csv('transfusion.csv')
x = df.drop('Frequency (times)', axis = 1, inplace = True)
y = df.iloc[:, 3]
x = df.iloc[:, 0:3]
x = ss.fit_transform(x)
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 266)
model = svm.fit(X_train, y_train)
y_pred = model.predict(X_test)
print('\nAccuracy Score = ', accuracy_score(y_test, y_pred))
print('\nPrecision Score = ', precision_score(y_test, y_pred))
print('\nRecall Score = ', recall_score(y_test, y_pred))
print('\nf1 Score = ', f1_score(y_test, y_pred))
print('\nConfusion Matrix:\n\n', confusion_matrix(y_test, y_pred))
print('\nClassification Report:\n\n', classification_report(y_test, y_pred))
plt.figure(figsize = (8, 6))
sns.heatmap(confusion_matrix(y_test, y_pred), annot = True, cmap = 'magma')
plt.show()
fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize = (16, 9))
sns.boxplot(df.iloc[:, 0], color = 'red', ax = axes[0, 0])
sns.boxplot(df.iloc[:, 1], color = 'green', ax = axes[0, 1])
sns.boxplot(df.iloc[:, 2], color = 'blue', ax = axes[1, 0])
sns.boxplot(df.iloc[:, 3], color = 'orange', ax = axes[1, 1])
axes[0, 0].set_title('Recency')
axes[0, 1].set_title('Frequency')
axes[1, 0].set_title('Monetary')
axes[1, 1].set_title('Time')
plt.show()
print('\nRecency:\n')
stats_recency = {'Mean':9.5, 'Median':7.0, 'Max':74, 'Min':0}
stats_recency = [{'Statistic': key, 'Value': value} for key, value in stats_recency.items()]
stats_recency = pd.DataFrame(stats_recency)
print(stats_recency)
print('\nFrequency:\n')
stats_frequency = {'Mean':5.5, 'Median':4.0, 'Max':50, 'Min':1}
stats_frequency = [{'Statistic': key, 'Value': value} for key, value in stats_frequency.items()]
stats_frequency = pd.DataFrame(stats_frequency)
print(stats_frequency)
print('\nMonetary:\n')
stats_monetary = {'Mean':1378.6, 'Median':1000, 'Max':12500, 'Min':250}
stats_monetary = [{'Statistic': key, 'Value': value} for key, value in stats_monetary.items()]
stats_monetary = pd.DataFrame(stats_monetary)
print(stats_monetary)
print('\nTime:\n')
stats_time = {'Mean':34.2, 'Median':28, 'Max':98, 'Min':2}
stats_time = [{'Statistic': key, 'Value': value} for key, value in stats_time.items()]
stats_time = pd.DataFrame(stats_time)
print(stats_time)
# Out:
# Accuracy Score =  0.8466666666666667
#
# Precision Score =  0.5
#
# Recall Score =  0.043478260869565216
#
# f1 Score =  0.08
#
# Confusion Matrix:
#
#  [[126   1]
#  [ 22   1]]
#
# Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.85      0.99      0.92       127
#            1       0.50      0.04      0.08        23
#
#     accuracy                           0.85       150
#    macro avg       0.68      0.52      0.50       150
# weighted avg       0.80      0.85      0.79       150
# Recency:
#
#   Statistic  Value
# 0      Mean    9.5
# 1    Median    7.0
# 2       Max   74.0
# 3       Min    0.0
#
# Frequency:
#
#   Statistic  Value
# 0      Mean    5.5
# 1    Median    4.0
# 2       Max   50.0
# 3       Min    1.0
#
# Monetary:
#
#   Statistic    Value
# 0      Mean   1378.6
# 1    Median   1000.0
# 2       Max  12500.0
# 3       Min    250.0
#
# Time:
#
#   Statistic  Value
# 0      Mean   34.2
# 1    Median   28.0
# 2       Max   98.0
# 3       Min    2.0

# %% [markdown]
# # SVM(RBF) without the column 'Monetary (c. c. blood)'

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
ss = StandardScaler()
svm = SVC(kernel = 'rbf')
df = pd.read_csv('transfusion.csv')
x = df.drop('Monetary (c.c. blood)', axis = 1, inplace = True)
y = df.iloc[:, 3]
x = df.iloc[:, 0:3]
x = ss.fit_transform(x)
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 46)
model = svm.fit(X_train, y_train)
y_pred = model.predict(X_test)
print('\nAccuracy Score = ', accuracy_score(y_test, y_pred))
print('\nPrecision Score = ', precision_score(y_test, y_pred))
print('\nRecall Score = ', recall_score(y_test, y_pred))
print('\nf1 Score = ', f1_score(y_test, y_pred))
print('\nConfusion Matrix:\n\n', confusion_matrix(y_test, y_pred))
print('\nClassification Report:\n\n', classification_report(y_test, y_pred))
plt.figure(figsize = (8, 6))
sns.heatmap(confusion_matrix(y_test, y_pred), annot = True, cmap = 'magma')
plt.show()
fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize = (16, 9))
sns.boxplot(df.iloc[:, 0], color = 'red', ax = axes[0, 0])
sns.boxplot(df.iloc[:, 1], color = 'green', ax = axes[0, 1])
sns.boxplot(df.iloc[:, 2], color = 'blue', ax = axes[1, 0])
sns.boxplot(df.iloc[:, 3], color = 'orange', ax = axes[1, 1])
axes[0, 0].set_title('Recency')
axes[0, 1].set_title('Frequency')
axes[1, 0].set_title('Monetary')
axes[1, 1].set_title('Time')
plt.show()
print('\nRecency:\n')
stats_recency = {'Mean':9.5, 'Median':7.0, 'Max':74, 'Min':0}
stats_recency = [{'Statistic': key, 'Value': value} for key, value in stats_recency.items()]
stats_recency = pd.DataFrame(stats_recency)
print(stats_recency)
print('\nFrequency:\n')
stats_frequency = {'Mean':5.5, 'Median':4.0, 'Max':50, 'Min':1}
stats_frequency = [{'Statistic': key, 'Value': value} for key, value in stats_frequency.items()]
stats_frequency = pd.DataFrame(stats_frequency)
print(stats_frequency)
print('\nMonetary:\n')
stats_monetary = {'Mean':1378.6, 'Median':1000, 'Max':12500, 'Min':250}
stats_monetary = [{'Statistic': key, 'Value': value} for key, value in stats_monetary.items()]
stats_monetary = pd.DataFrame(stats_monetary)
print(stats_monetary)
print('\nTime:\n')
stats_time = {'Mean':34.2, 'Median':28, 'Max':98, 'Min':2}
stats_time = [{'Statistic': key, 'Value': value} for key, value in stats_time.items()]
stats_time = pd.DataFrame(stats_time)
print(stats_time)
# Out:
# Accuracy Score =  0.86
#
# Precision Score =  0.7857142857142857
#
# Recall Score =  0.3793103448275862
#
# f1 Score =  0.5116279069767441
#
# Confusion Matrix:
#
#  [[118   3]
#  [ 18  11]]
#
# Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92       121
#            1       0.79      0.38      0.51        29
#
#     accuracy                           0.86       150
#    macro avg       0.83      0.68      0.71       150
# weighted avg       0.85      0.86      0.84       150
# Recency:
#
#   Statistic  Value
# 0      Mean    9.5
# 1    Median    7.0
# 2       Max   74.0
# 3       Min    0.0
#
# Frequency:
#
#   Statistic  Value
# 0      Mean    5.5
# 1    Median    4.0
# 2       Max   50.0
# 3       Min    1.0
#
# Monetary:
#
#   Statistic    Value
# 0      Mean   1378.6
# 1    Median   1000.0
# 2       Max  12500.0
# 3       Min    250.0
#
# Time:
#
#   Statistic  Value
# 0      Mean   34.2
# 1    Median   28.0
# 2       Max   98.0
# 3       Min    2.0

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
ss = StandardScaler()
svm = SVC(kernel = 'rbf')
df = pd.read_csv('footulcer.csv')
x = df.drop('Monetary (c.c. blood)', axis = 1, inplace = True)
y = df.iloc[:, 3]
x = df.iloc[:, 0:3]
x = ss.fit_transform(x)
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 46)
model = svm.fit(X_train, y_train)
y_pred = model.predict(X_test)
print('\nAccuracy Score = ', accuracy_score(y_test, y_pred))
print('\nPrecision Score = ', precision_score(y_test, y_pred))
print('\nRecall Score = ', recall_score(y_test, y_pred))
print('\nf1 Score = ', f1_score(y_test, y_pred))
print('\nConfusion Matrix:\n\n', confusion_matrix(y_test, y_pred))
print('\nClassification Report:\n\n', classification_report(y_test, y_pred))
plt.figure(figsize = (8, 6))
sns.heatmap(confusion_matrix(y_test, y_pred), annot = True, cmap = 'magma')
plt.show()
fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize = (16, 9))
sns.boxplot(df.iloc[:, 0], color = 'red', ax = axes[0, 0])
sns.boxplot(df.iloc[:, 1], color = 'green', ax = axes[0, 1])
sns.boxplot(df.iloc[:, 2], color = 'blue', ax = axes[1, 0])
sns.boxplot(df.iloc[:, 3], color = 'orange', ax = axes[1, 1])
axes[0, 0].set_title('Recency')
axes[0, 1].set_title('Frequency')
axes[1, 0].set_title('Monetary')
axes[1, 1].set_title('Time')
plt.show()
print('\nRecency:\n')
stats_recency = {'Mean':9.5, 'Median':7.0, 'Max':74, 'Min':0}
stats_recency = [{'Statistic': key, 'Value': value} for key, value in stats_recency.items()]
stats_recency = pd.DataFrame(stats_recency)
print(stats_recency)
print('\nFrequency:\n')
stats_frequency = {'Mean':5.5, 'Median':4.0, 'Max':50, 'Min':1}
stats_frequency = [{'Statistic': key, 'Value': value} for key, value in stats_frequency.items()]
stats_frequency = pd.DataFrame(stats_frequency)
print(stats_frequency)
print('\nMonetary:\n')
stats_monetary = {'Mean':1378.6, 'Median':1000, 'Max':12500, 'Min':250}
stats_monetary = [{'Statistic': key, 'Value': value} for key, value in stats_monetary.items()]
stats_monetary = pd.DataFrame(stats_monetary)
print(stats_monetary)
print('\nTime:\n')
stats_time = {'Mean':34.2, 'Median':28, 'Max':98, 'Min':2}
stats_time = [{'Statistic': key, 'Value': value} for key, value in stats_time.items()]
stats_time = pd.DataFrame(stats_time)
print(stats_time)
